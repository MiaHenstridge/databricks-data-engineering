# %% [markdown]
# # Extract data from the address files
# 1. Read all the addresses file
# 2. Create addresses table in th Bronze layer

# %% [markdown]
# ## 1. Read all the addresses files

# %%
# %sql
# -- SELECT *
# -- FROM csv.`/Volumes/gizmobox/landing/operational_data/addresses/`;
df = spark.read.csv('/Volumes/gizmobox/landing/operational_data/addresses/', 
                    header=True, 
                    sep='\t')

display(df)

# %% [markdown]
# ## 2. Write to Bronze layer

# %%
# %sql
# CREATE OR REPLACE VIEW gizmobox.bronze.v_addresses 
# AS 
# SELECT *
# FROM read_files(
#   '/Volumes/gizmobox/landing/operational_data/addresses/', 
#   format =>'csv',
#   header => true,
#   delimiter => '\t');

df.writeTo('gizmobox.bronze.py_addresses').createOrReplace()

# %%
# %sql
SELECT *
FROM gizmobox.bronze.py_addresses;
