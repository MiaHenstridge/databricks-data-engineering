# %% [markdown]
# # Databricks Magic Commands
# * **%python, %sql, %scala, \%r**: Switch to a different language for a specific cell
# * **%md**: Markdown
# * **%fs**: Run file system Commands
# * **%sh**: Run shell commands (Driver Node only)
# * **%pip**: Install Python libraries
# * **%run**: Include/import other notebook into the current notebook

# %% [markdown]
# ## %fs: Run file system commands

# %%
# %fs ls /databricks-datasets/

# %% [markdown]
# ## %sh: Run shell commands (driver node only)

# %%
# %sh
# see all processes running on all nodes
ps

# %% [markdown]
# ## %pip: Install Python libraries

# %%
# %pip list

# %%
# %pip install faker

# %% [markdown]
# ## %run: Include/import another notebook into the current notebook

# %%
# %run "/Workspace/Users/nongngocmai22@gmail.com/dea-course/dea01-databricks-lakehouse-platform/2.1. Environment variables and functions"

# %%
env

# %%
print_env_info()
