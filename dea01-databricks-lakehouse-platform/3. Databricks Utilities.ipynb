# %% [markdown]
# # Databricks Utilities
# * File system utilities
# * Secrets utilities
# * Widget utilities
# * Notebook Workflow utilities

# %% [markdown]
# ## File system utilities

# %%
# %fs ls /

# %%
dbutils.fs.ls('/')

# %%
display(dbutils.fs.ls('/databricks-datasets/'))   # more readable output with display()

# %%
items = dbutils.fs.ls('/databricks-datasets/')

# count number of folders
folder_count = len([item for item in items if item.name.endswith('/')])
print(folder_count)

# %%
# view all available utilities
dbutils.help()
