-- %% [markdown]
-- # Extract data from orders JSON file
-- 1. Query orders file using json format
-- 2. Query orders file using text format
-- 3. Create orders view in Bronze schema

-- %% [markdown]
-- ## 1. Query orders file using json format

-- %%
SELECT *
FROM json.`/Volumes/gizmobox/landing/operational_data/orders/`;

-- %% [markdown]
-- ## 2. Query orders file using TEXT format

-- %%
SELECT *
FROM text.`/Volumes/gizmobox/landing/operational_data/orders/`;

-- %% [markdown]
-- ## 3. Create orders view in Bronze schema

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_orders 
AS
SELECT * 
FROM text.`/Volumes/gizmobox/landing/operational_data/orders/`;

-- %%
SELECT * FROM gizmobox.bronze.v_orders;
